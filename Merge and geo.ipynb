# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import geopandas as gpd
from geopandas.tools import sjoin
from matplotlib.offsetbox import AnchoredText
import matplotlib.cm
import matplotlib.colors as colors
import geoplot as gplt
import matplotlib.animation as animation

# %%
# All=pd.read_csv("https://raw.githubusercontent.com/govex/COVID-19/master/data_tables/JHU_USCountymap/df_Counties2020.csv")
County_shape = gpd.read_file("Counties\\USCounties_JHUmap\\USCounties_JHUmap.shp", driver='shapefile')
# Fin=pd.merge(County_shape,All,
#                  on='Countyname')
# print(Fin)
County_shape.to_file("Counties\\US_latest_poly.geojson", driver='GeoJSON')

# %%
#Fin.to_file("Counties\\US_latest_poly.geojson", driver='GeoJSON')

# %%
#Fin.to_file("Counties\\US_latest_poly.shp")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-30d61fe06e64> in <module>
# ----> 1 Fin.to_file("Counties\\US_latest_poly.shp")
#
# ~\Anaconda3\lib\site-packages\geopandas\geodataframe.py in to_file(self, filename, driver, schema, **kwargs)
#     502         from geopandas.io.file import to_file
#     503
# --> 504         to_file(self, filename, driver, schema, **kwargs)
#     505
#     506     def to_crs(self, crs=None, epsg=None, inplace=False):
#
# ~\Anaconda3\lib\site-packages\geopandas\io\file.py in to_file(df, filename, driver, schema, **kwargs)
#     128             filename, "w", driver=driver, crs=df.crs, schema=schema, **kwargs
#     129         ) as colxn:
# --> 130             colxn.writerecords(df.iterfeatures())
#     131
#     132
#
# ~\Anaconda3\lib\site-packages\fiona\collection.py in writerecords(self, records)
# ...

# %%
# All=pd.read_csv("https://raw.githubusercontent.com/govex/COVID-19/master/data_tables/JHU_USCountymap/df_Counties2020.csv")
County_shape = gpd.read_file("Counties\\USCounties_JHUmap\\USCounties_JHUmap.shp", driver='shapefile')
# Fin=pd.merge(County_shape,All,
#                  on='Countyname')

# %%
County_shape
# Out:
#      Countyname  ST_Name ST_Abbr ST_ID   FIPS  FatalityRa  Confirmedb  \
# 0       Autauga  Alabama      AL    01  01001    1.990812     1174.44
# 1       Baldwin  Alabama      AL    01  01003    0.897666      510.96
# 2       Barbour  Alabama      AL    01  01005    0.544959     1475.02
# 3          Bibb  Alabama      AL    01  01007    0.480769      928.57
# 4        Blount  Alabama      AL    01  01009    0.366300      471.99
# ...         ...      ...     ...   ...    ...         ...         ...
# 3253       None     None    None  None  00000         NaN         NaN
# 3254       None     None    None  None  00000         NaN         NaN
# 3255       None     None    None  None  00000         NaN         NaN
# 3256       None     None    None  None  00000         NaN         NaN
# 3257       None     None    None  None  00000         NaN         NaN
#
#       DeathsbyPo  PCTPOVALL_  Unemployme  ...  Not_Hisp   NonHisp Age_Less15  \
# ...
